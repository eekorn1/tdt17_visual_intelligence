# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/tdt17_visual_intelligence/yolov5

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %% [markdown]
# ## Pre-training predictions

# %%
# !python benchmarks.py --img 640 --data norway.yaml --weights yolov5x.pt

# %% [markdown]
# ## Initial Training

# %%
# !python train.py --img 640 --batch 32 --epochs 64 --data norway.yaml --weights yolov5x.pt --cache ram

# %%
# !python benchmarks.py --img 640 --data norway.yaml --weights ./runs/train/exp/weights/best.pt

# %% [markdown]
# ## Hyperparameter Tuning

# %%
# !python train.py --img 640 --batch 16 --epochs 10 --data norway_small.yaml --weights ./runs/train/exp/weights/best.pt --cache ram --evolve 100

# %% [markdown]
# ## Final Training step
# ### Part 1

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data norway_drop_empty.yaml --weights ./runs/train/exp/weights/best.pt --cache ram --hyp ./runs/evolve/exp/hyp_evolve.yaml

# %%
# !python benchmarks.py --img 640 --data norway_drop_empty.yaml --weights ./runs/train/exp2/weights/best.pt

# %% [markdown]
# ### Part 2

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data norway_drop_empty.yaml --weights ./runs/train/exp2/weights/last.pt --cache ram --hyp ./runs/evolve/exp/hyp_evolve.yaml

# %%
# !python benchmarks.py --img 640 --data norway_drop_empty.yaml --weights ./runs/train/exp3/weights/best.pt

# %% [markdown]
# ## Predictions on Test set

# %%
# !python detect.py --weights ./runs/train/exp30/weights/best.pt --source ../datasets/test/images/ --save-txt
